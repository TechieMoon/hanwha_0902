# %% [markdown]
# W3 Schools
# https://www.w3schools.com/python/default.asp

# %%
print("테스트")
# Out:
# 테스트

# %%
print("테스트2")
# Out:
# 테스트2

# %%
print(30)
# Out:
# 30

# %%
x = str(3)
y = int(3)
z = float(3)

print(x)
print(y)
print(z)
# Out:
# 3
# 3
# 3.0

# %%
x = 5
y = "John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
x = "John"
y = "John2"
print(x)
print(y)
# Out:
# John
# John2

# %%
x = "Python"
y = "is"
z = "awesome"
print(x,y,z)
# Out:
# Python is awesome

# %%
x = 10
y = 20
print(x + y)
# Out:
# 30

# %%
x = "Python"
y = "is"
z = "awesome"

# %%
x = 5
y = "John"
print(str(x) + y)
# Out:
# 5John

# %%
x = "awesome"

def myfunc():
  x = "fantastic"
  print("Python is " + x)

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic
# Python is awesome

# %%
def myfunc():
  global x
  x = "fantastic"

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic

# %%
x = """abcde
fgh
d""" + 'fff'
print(x)
# Out:
# abcde
# fgh
# dfff
