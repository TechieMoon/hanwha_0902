# %%
i = 1
while i < 6:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 1
while i < 6:
    print(i)
    if i == 3:
        break 
    i += 1
# Out:
# 1
# 2
# 3

# %%
i = 0 
while i < 6:
    i += 1 
    if i == 3:
        continue 
    print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %%
i = 1
while i < 6:
    print(i) 
    i += 1 
else:
    print("i는 더이상 6보다 작지 않아요")
# Out:
# 1
# 2
# 3
# 4
# 5
# i는 더이상 6보다 작지 않아요
