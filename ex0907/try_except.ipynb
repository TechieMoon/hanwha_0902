# %%
try:
    print(x)
except:
    print("An exception occurred")
# Out:
# An exception occurred

# %% [markdown]
# x가 정의되지 않았으므로
# try에서 에러가 발생 -> 프로그램이 종료되지 않고 except문을 실행
# 따라서 "An exception occurred"가 출력됨

# %%
try:
  print(x)
except NameError:
  print("Variable x is not defined")
except:
  print("Something else went wrong")
# Out:
# Variable x is not defined

# %% [markdown]
# Error도 종류가 있음
# NameError가 발생했으므로 NameError가 있는 except가 실행됨

# %%
try:
  print("Hello")
except:
  print("Something went wrong")
else:
  print("Nothing went wrong")
# Out:
# Hello
# Nothing went wrong

# %% [markdown]
# try가 에러가 발생하지 않으면 else 실행

# %%
try:
  print(x)
except:
  print("Something went wrong")
else:
  print("Nothing went wrong")
# Out:
# Something went wrong

# %% [markdown]
# try가 에러가 발생하면 except 실행하고 else는 실행 안함

# %%
try:
  f = open("demofile.txt")
  try:
    f.write("Lorum Ipsum")
  except:
    print("Something went wrong when writing to the file")
  finally:
    f.close()
except:
  print("Something went wrong when opening the file")
# Out:
# Something went wrong when opening the file

# %% [markdown]
# finally 구문은 try가 잘 실행되든 error가 발생하든 마지막에 실행
# 파일은 사용하고 꼭 닫아야한다.
